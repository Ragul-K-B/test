# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragul-K-B/test/blob/main/demographic_data_analyzer_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('adultcrctuh.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d48ea49c6b6b> in <cell line: 1>()
# ----> 1 df=pd.read_csv('adultcrctuh.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# ...

# %%
df.head(10)
# Out:
#    age         workclass   fnlwgt  education   education-num   \
# 0   39          State-gov   77516   Bachelors              13
# 1   50   Self-emp-not-inc   83311   Bachelors              13
# 2   38            Private  215646     HS-grad               9
# 3   53            Private  234721        11th               7
# 4   28            Private  338409   Bachelors              13
# 5   37            Private  284582     Masters              14
# 6   49            Private  160187         9th               5
# 7   52   Self-emp-not-inc  209642     HS-grad               9
# 8   31            Private   45781     Masters              14
# 9   42            Private  159449   Bachelors              13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# education-num      0
# marital-status     0
# occupation         0
#  relationship      0
# race               0
# sex                0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# ative-country      0
# salary             0
# dtype: int64

# %%
sns.pairplot(df,diag_kind='kde')

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other', nan], dtype=object)

# %%
age=[]
age = df[df['sex ']==' Male']['age']

# %%
age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d075b0315d53> in <cell line: 1>()
# ----> 1 age
#
# NameError: name 'age' is not defined

# %%
edu= df[df['sex ']==' Male'][df['age']==' 38']['education ']
# Out:
# <ipython-input-108-2488b72d8921>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   edu= df[df['sex ']==' Male'][df['age']==' 38']['education ']

# %%
print(list(age))
print(list(edu))
# Out:
# [39, 50, 38, 53, 52, 42, 37, 30, 32, 40, 34, 25, 32, 38, 40, 35, 43, 56, 19, 54, 39, 49, 23, 20, 45, 30, 22, 48, 21, 31, 48, 31, 53, 24, 25, 57, 53, 41, 29, 50, 47, 43, 46, 35, 41, 30, 30, 32, 48, 42, 29, 36, 49, 25, 19, 29, 23, 79, 27, 40, 67, 31, 18, 52, 59, 49, 33, 30, 57, 34, 29, 48, 37, 32, 76, 44, 29, 32, 30, 42, 24, 38, 56, 53, 56, 49, 55, 22, 40, 30, 29, 19, 31, 35, 39, 38, 37, 38, 43, 20, 49, 61, 19, 70, 22, 64, 21, 52, 48, 23, 71, 29, 42, 45, 39, 46, 18, 27, 28, 51, 27, 28, 21, 34, 18, 33, 44, 30, 40, 37, 34, 58, 24, 41, 47, 41, 23, 36, 35, 24, 19, 51, 36, 35, 44, 37, 60, 54, 37, 38, 45, 25, 31, 64, 90, 54, 66, 35, 25, 28, 59, 41, 38, 23, 40, 24, 20, 38, 56, 58, 40, 45, 19, 58, 42, 50, 45, 17, 59, 26, 37, 19, 64, 61, 17, 50, 27, 43, 44, 42, 21, 57, 41, 50, 50, 36, 29, 21, 65, 24, 38, 48, 31, 55, 26, 35, 41, 26, 34, 22, 24, 77, 39, 43, 35, 76, 63, 58, 66, 41, 26, 47, 55, 53, 17, 30, 49, 19, 45, 26, 38, 36, 33, 43, 67, 56, 31, 33, 26, 33, 46, 59, 38, 65, 40, 26, 62, 43, 43, 2
# ...

# %%
avgmen=age.mean()
avgmen.round(1)
# Out:
# 39.4

# %%
# printing all columns of the dataframe
print(df.columns.tolist())
# Out:
# ['age', 'workclass ', 'fnlwgt', 'education ', 'education-num ', 'marital-status', 'occupation', ' relationship', 'race', 'sex ', 'capital-gain', 'capital-loss', 'hours-per-week ', 'ative-country', 'salary']

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
white=df[df['race']==' White']['race']
black=df[df['race']==' Black']['race']
asia=df[df['race']==' Asian-Pac-Islander']['race']
amer=df[df['race']==' Amer-Indian-Eskimo']['race']
other=df[df['race']==' Other']['race']

# %%
cwhite=white.count()
cblack=black.count()
casia=asia.count()
camer=amer.count()
cother=other.count()

# %%
print(cwhite)
print(cblack)
print(casia)
print(camer)
print(cother)
# Out:
# 27816
# 3124
# 1039
# 311
# 271

# %%
asia
# Out:
# 11        Asian-Pac-Islander
# 14        Asian-Pac-Islander
# 27        Asian-Pac-Islander
# 93        Asian-Pac-Islander
# 139       Asian-Pac-Islander
#                 ...
# 32457     Asian-Pac-Islander
# 32486     Asian-Pac-Islander
# 32531     Asian-Pac-Islander
# 32533     Asian-Pac-Islander
# 32553     Asian-Pac-Islander
# Name: race, Length: 1039, dtype: object

# %%
df.head()
# Out:
#    age         workclass   fnlwgt  education   education-num   \
# 0   39          State-gov   77516   Bachelors              13
# 1   50   Self-emp-not-inc   83311   Bachelors              13
# 2   38            Private  215646     HS-grad               9
# 3   53            Private  234721        11th               7
# 4   28            Private  338409   Bachelors              13
#
#         marital-status          occupation    relationship    race     sex   \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week    ative-country  salary
# ...

# %%
df['education '].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
bch=df[df['education ']==' Bachelors']['education ']

# %%
cbch=bch.count()
ctot=df['education '].count()

# %%
bper=((cbch/ctot)*100).round(1)
bper
# Out:
# 16.4

# %%
wit50 = df[df['education '].isin([' Bachelors',' Masters',' Doctrate'])]
wito50= df[~df['education '].isin([' Bachelors',' Masters',' Doctrate'])]

# %%
wit50per=((wit50['education '].count())/df['education '].count())*100
wit50per.round(1)
# Out:
# 21.7

# %%
wito50per=((wito50['education '].count())/df['education '].count())*100
wito50per.round(1)
# Out:
# 78.3

# %%
min=df['hours-per-week '].min()
min
# Out:
# 1

# %%
min50=df[df['hours-per-week ']==min]['salary']
min50.head()
min50.unique()
# Out:
# array([' >50K', ' <=50K'], dtype=object)

# %%
min50lis=[]
min50=list(min50)
for i in min50:
  if i==" >50K":
    min50lis.append(i)
min50c=len(min50lis)
min50c
min50cpercent=(min50c/df['sex '].count())*100
min50cpercent
# Out:
# 0.006142317496391388

# %%
occup=df[df['salary']==' >50K']
occup['occupation'].value_counts()
popoccup=' Exec-managerial'
popoccup
# Out:
# ' Exec-managerial'

# %%
occup['occupation'].unique()
# Out:
# array([' Exec-managerial', ' Prof-specialty', ' Craft-repair',
#        ' Tech-support', ' ?', ' Sales', ' Adm-clerical',
#        ' Protective-serv', ' Other-service', ' Machine-op-inspct',
#        ' Farming-fishing', ' Transport-moving', ' Handlers-cleaners',
#        ' Armed-Forces', ' Priv-house-serv'], dtype=object)

# %%
# printing all columns of the dataframe
print(df.columns.tolist())
# Out:
# ['age', 'workclass ', 'fnlwgt', 'education ', 'education-num ', 'marital-status', 'occupation', ' relationship', 'race', 'sex ', 'capital-gain', 'capital-loss', 'hours-per-week ', 'ative-country', 'salary']

# %%
country_count = occup.groupby('ative-country')['ative-country'].count()

country_count
# Out:
# ative-country
#  ?                      146
#  Cambodia                 7
#  Canada                  39
#  China                   20
#  Columbia                 2
#  Cuba                    25
#  Dominican-Republic       2
#  Ecuador                  4
#  El-Salvador              9
#  England                 30
#  France                  12
#  Germany                 44
#  Greece                   8
#  Guatemala                3
#  Haiti                    4
#  Honduras                 1
#  Hong                     6
#  Hungary                  3
#  India                   40
#  Iran                    18
#  Ireland                  5
#  Italy                   25
#  Jamaica                 10
#  Japan                   24
#  Laos                     2
#  Mexico                  33
#  Nicaragua                2
#  Peru                     2
#  Philippines             61
#  Poland                  12
#  Portugal                 4
#  Puerto-Rico             12
# ...

# %%
countrypercent=(3882/(df['sex '].count()))*100
countrypercent=countrypercent.round(1)
country='United-States '
print(country,countrypercent)
# Out:
# United-States  21.8

# %%
#printing the found values
print("people of each race are represented in this dataset")
df.groupby('race')['race'].count()
print("average age of men",avgmen.round(1))
print("percentage of people who have a Bachelor's degree",bper)
print("percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K",wit50per.round(1))
print("What percentage of people without advanced education make more than 50K",wito50per.round(1))
print("What is the minimum number of hours a person works per week",min)
print("What is the minimum number of hours a person works per week",min50cpercent)
print("country has the highest percentage of people that earn >50K and what is that percentage?",country,'&',countrypercent)
print('the most popular occupation for those who earn >50K in India',popoccup)
# Out:
# people of each race are represented in this dataset
# average age of men 39.4
# percentage of people who have a Bachelor's degree 16.4
# percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K 21.7
# What percentage of people without advanced education make more than 50K 78.3
# What is the minimum number of hours a person works per week 1
# What is the minimum number of hours a person works per week 0.006142317496391388
# country has the highest percentage of people that earn >50K and what is that percentage? United-States  & 21.8
# the most popular occupation for those who earn >50K in India  Exec-managerial
